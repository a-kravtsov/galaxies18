# %% [markdown]
# ## Astro 304 "Galaxies"

# %% [markdown]
# ### Cooling and heating processes during galaxy formation

# %%
# setup notebook for inline figures
# %matplotlib inline
import numpy as np
# %load_ext autoreload
# %autoreload 2

# import pyplot and set some parameters to make plots prettier
import matplotlib.pyplot as plt
from code.plot_utils import plot_pretty
plot_pretty()

# %% [markdown]
# ### Heating processes
#
# Compression, ionization, cosmic rays.

# %% [markdown]
# ### Re-ionization of the universe and heating of the intergalactic gas
#
# At $z_{\rm rec}\approx 1100$ the electrons and ions recombined, which allowed photons we know detect as the Cosmic Microwave Background (CMB) to propagate freely.
#
# Observations show, however, that by $z\approx 6$ intergalactic medium in the universe is ionized. So between $z=1100$ and $z\approx 6$ the gas must have been *re-ionized*. The process is called *reionization* and is almost certainly due to the UV photons emitted by young massive stars in the first galaxies at these high redshifts.
#
# The UV photons ionize neutral atoms and freed electrons carry extra energy which gets converted into gas temperature. Ionization by photons with spectrum typical of that of massive stars heats the gas to $T\approx 5000-10000 K$. This heating raises the *Jeans mass* of the integalactic gas and leads to suppression of gas accretion onto halos with the "virial" temperature (where $R=R_\Delta$; $M=M(<R_\Delta)$):
#
# $$kT=\mu m_p\frac{GM}{R}$$
#
# less than the temperature of the gas.

# %% [markdown]
# ### Suppression of gas accretion on small-mass halos and "filtering mass"
#
# The mathematical formalism describing effect of such re-heating on the evolution of perturbations is presented in <a href="http://adsabs.harvard.edu/abs/2000ApJ...542..535G">Gnedin (2000).</a> The quantitative effect on accretion of baryons on a collapsing peak is calibrated using
#  numerical simulations of galaxy formation  (e.g., <a href="http://adsabs.harvard.edu/abs/2006MNRAS.371..401H">Hoeft et al 2006</a>, <a href="http://adsabs.harvard.edu/abs/2008MNRAS.390..920O">Okamoto et al 2008</a>). It predicts that baryon fractions in halos of mass $M$ at redshift $z$ is modified from a constant value $\bar{f}_{\rm b}$ as:
#
# $$
#  f_{\rm b}(M,z)=\bar{f}_{\rm b}\left\{1+(2^{\alpha/3-1}-1)\left[\frac{M}{M_{\rm c}(z)}\right]^{-\alpha}\right\}^{-3/\alpha},
# $$
#
# with $\alpha=2$.
#
# The cutoff mass $M_{\rm c}$ is derived from simulations of galaxy formation.
# For example, $M_{\rm c}(z)$, in figures of <a href="http://adsabs.harvard.edu/abs/2008MNRAS.390..920O">Okamoto et al (2008)</a>
# is well approximated by the following formula:
#
# $$
#     M_{\rm c}(z) = 6\times 10^9h^{-1}\ M_\odot\,\exp(-0.63z),\ \ \mathrm{for}\ z<9,
# $$
#
# while $M_{\rm c}$ can be assumed to be $\approx 10^5-10^6h^{-1}\ M_\odot$ at $z>9$, because temperature of the gas is much smaller before reionization.

# %% [markdown]
# ### Cooling processes
#
# Unlike dark matter, baryonic matter radiate away the internal energy it acquires during gravitational collapse thanks to many radiative (i.e. cooling) processes, which can be classified into four main classes:
#
# 1) <b>Free-free emission (aka brehmsstrahlung)</b>  produced by charged particles moving in the EM field of other changed particles - e.g., electron moving past a proton.
#
# 2) <b>bound-bound emission</b>: electron transitions from level to level in atoms and ions. As atoms or ions (with bound electrons present) absorb photons or bump into each other, electron(s) can get excited to higher energy levels. Subsequent decay back to ground state and emission of photon(s). If plasma has low optical depth to emitted photons, they will leave the system, carrying the energy with them.
#
# 3) <b>free-bound emission</b> when an electron recombines with an ion.
#
# 4) <b>Compton cooling</b>, in which the electrons scatter off the CMB photons which have low energy due to redshifting at the redshifts relevant for galaxies.
# Free electrons must exist - i.e., gas must be at least partially ionized - for the Compton cooling to operate.

# %% [markdown]
# ### Cooling: scaling with gas density
#
# The Compton cooling depends only on the plasma density and temperature and energy density of the CMB photons (which is set by observations).
#
# $$
# \mathcal{L}_{\rm Compon}=\frac{4kT_e}{m_ec^2}c\sigma_{\rm T}n_e aT_{\rm CMB}^4
# $$
#
# The other relevant processes all involve two particles - i.e., electron and ion, ion-ion, or electron-ion. For neutral or partially ionized gas it could be neutral atoms, neutral-electron, or electron-ionized atoms. Thus, the cooling rate due to these processes is proportional to the square of the gas density.
#
# The cooling rates is thus often quantified in terms of the so-called *cooling function* $\Lambda$:
#
# $$\Lambda(T,Z,...)= \frac{\mathcal{L}}{n^2},$$
#
# where $\mathcal{L}$ is the cooling rate in, say, ergs per second.

# %% [markdown]
# ### Cooling and heating processes
#
# For the hydrogen-helium plasma, the processes that contribute to cooling and heating and the relevant "chemistry" of atoms and ions can be written down in a page or so of equation (e.g., see Appendix A.2 in <a href="http://adsabs.harvard.edu/abs/2011ApJ...728...88G">Gnedin & Kravtsov (2011)</a>.
#
# <img src="http://astro.uchicago.edu/~andrey/classes/a304/fig/gk11_primordial_chem.PNG" width="500" height="500"></img>

# %% [markdown]
# ### Cooling processes in the primordial (zero metallicity) gas
#
# This is Figure 1 from <a href="http://adsabs.harvard.edu/abs/1997ApJ...477....8W">Weinberg et al. (1997)</a>:
#
# <img src="http://astro.uchicago.edu/~andrey/classes/a304/fig/weinberg_etal97_cool_func_fig1.png" width="500" height="500"></img>

# %% [markdown]
# ### Cooling processes in gas enriched with heavy elements (Z>0)
#
# As gas gets enriched with heavy elements, the number of different ions present and possible processes of their mutual interactions becomes large. Here is a figure from <a href="http://adsabs.harvard.edu/abs/2009MNRAS.393...99W">Wiersma et al. (2008)</a> (see also $\Lambda$ and $H$ tables and movies <a href="http://www.strw.leidenuniv.nl/WSS08">here</a>)
#
# <img src="http://astro.uchicago.edu/~andrey/classes/a304/fig/wiersma08_Lambda_Z_dependence.PNG" width="500"></img>

# %% [markdown]
# ### Cooling and heating function tables
#
# It is possible to follow reaction rate for dozens, or even hundreds, of atoms and ions and to track their abundance in a model (e.g., <a href="http://adsabs.harvard.edu/abs/2014MNRAS.442.2780R">Richings et al. 2014</a>), but this is most often is not necessary because gas is often in the collisional and ionization equilibrium. Thus, such equilibrium can be assumed and the rates can be pre-computed into interpolation table as a function of metallicity, UV background intensity, and gas density,  using a plasma emission code, such as <a href="http://www.nublado.org/">Cloudy</a>.
#
# Given that cooling rates depend trivially on $n^2$, the actual tabulated quantity is so-called *cooling function*: $\Lambda(T,Z,...)\equiv \mathcal{L}/n^2$.

# %% [markdown]
# ### Cooling and heating functions: example
#
# Cooling and heating functions for the primordial metallicity ($Z=M_{\rm Z}/M_{\rm gas}=0$) and solar metallicity, $Z=Z_\odot=0.02$ and for two gas densities: $n=10^{-3}\ \mathrm{cm^{-3}}$ (left) and $n=10\ \mathrm{cm^{-3}}$ (right).
# The heating rate is due to cosmic UV background estimated at $z=0$.
#
#  The plotted functions were generated using accurate approximations of  <a href="http://www.nublado.org/">Cloudy code</a> calculations by <a href="http://adsabs.harvard.edu/abs/2012ApJS..202...13G">Gnedin & Hollon (2012)</a>. You will find the code that reads the tables and produces this plot in this notebook.
#
# <img src="http://astro.uchicago.edu/~andrey/classes/a304/fig/chf.png" width="600"></img>

# %% [markdown]
# ### Cooling time
#
# *The cooling time* is a characteristic time scale over which plasma loses its internal energy: $\dot{e}=e/t_{\rm cool}$, where $\dot{e}=n^2(H-L)$ is the net rate of heating/cooling.
# The cooling time also depends on the physical gas density: $n(r)=\rho_{\rm gas}(r)/(\mu m_p)=f_{\rm gas}\rho_{\rm tot}/(\mu m_p)$, where the mean molecular weight for ionized plasma is $\mu\approx 0.6$ and $m_p=1.67262\times 10^{-24}\ \rm g$ is the mass of proton:
#
# $$
# t_{\rm cool}=\frac{e}{\dot{e}}=\frac{nkT}{(\gamma-1)n^2(H-\Lambda)},
# $$
#
# where $\gamma=5/3$ for ionized plasma.
#
# The *cooling time* for the Compton cooling of ideal monatomic gas is:
# $$
# t_{\rm Compton}\approx \frac{3}{2}\frac{n_ekT_e}{\mathcal{L_{\rm Compton}}}=\frac{3m_ec}{4\sigma_Ta_rT_{\rm CMB}^4},
# $$
#
# i.e., it is independent of density. The Compton cooling is only shorter than or comparable to the Hubble time (current age of the universe) at $z>5-6$ and thus is a significant cooling process at these early epochs. It is subdominant at lower $z.$

# %% [markdown]
# ### Cooling time as a function of halo mass
#
# When gas accretes onto halos it has $T$ of a few thousand K (set by the cosmic UV background) which corresponds to sound speed: $c_s=\sqrt{\gamma kT/(\mu m_p)}$ of a few km/s. However, it will achieve velocity of order halo circular velocity - i.e., $\sim 200$ km/s for the Milky Way halo. Its motion, thus, will be highly supersonic. Supersonic flows generally quickly develop *shocks*.
#
# Shocks are discontinuities in flow properties - jumps of density, velocity, temperature, entropy - convert gas kinetic energy into internal energy via viscosity.
#
# Let's assume that gas gets shocked at the virial radius corresponding to density contrast of $\delta\approx 100$ and reaches temperature of $T\sim T_{\rm vir}= \mu m_p/k \times GM_{\rm vir}/R_{\rm vir}$. The density contrast at the virial radius does not depend on halo mass, but $T_{\rm vir}$ does. Thus, *the cooling time of gas will be a function of halo mass.*
#
# $$
# t_{\rm cool}=\frac{e}{\dot{e}}=\frac{nkT}{(\gamma-1)n^2(H-\Lambda)}=\frac{\mu m_p}{(\gamma-1)n_{\rm vir}(H-\Lambda)}\frac{GM_{\rm vir}}{R_{\rm vir}},
# $$
#
# where $\gamma=5/3$ for non-molecular gas, $n_{\rm vir}=\Omega_b\rho_{\rm crit}(z)(1+\delta_{\rm vir})/(\mu m_p)$ where $\mu$ is the mean particle weight per proton mass $m_p$: $\mu\approx 0.6$ for fully ionized plasma.

# %% [markdown]
# ### Cooling time as a function of halo mass
#
# Here is a result of such calculation where I used definition of halo mass to be the mass enclosed within the radius within which density contrast is $200\rho_{\rm crit}$. You can find the code that does the calculation and produces this figure using Gnedin & Hollon tables in the notebook.
#
# The figure shows that the cooling time is much smaller than the age of the universe for small mass halos, but becomes longer than the age of the universe for $M\geq 10^{12}\ M_\odot$. Thus, the gas that accretes on such massive halos and gets shocked to the virial temperature of such halos cannot cool. This explains why we observe hot, X-ray emitting gas in groups and clusters of galaxies.
#
# <img src="http://astro.uchicago.edu/~andrey/classes/a304/fig/tcool_M200c.png" align="center" width="500"></img>

# %%
from code.setup.setup import data_home_dir

def Lambda_cool(Tgas, Zmet = 0.3, init=True):
    """
    cooling function based on Gnedin & Hollon tables
    input: 
    Tgas = gas temperature in K
    Zmet = gas metallicity in units of solar metallicity
        metallicity dependence is not implemented yet. calculations done for Z = 0.2Zsun.
    output:
    Lambda(T,z) = cooling function in ergs*cm^3/s
    """
    if init:
        dummy = np.loadtxt(data_home_dir()+'cool_table_n1e-3.dat', unpack=True) 
        lTgh = dummy[0]; heat = dummy[3]; cool = dummy[4]
        Lambda_cool.cfunc = UnivariateSpline(lTgh, np.log10(np.abs(heat-cool)), s=0.0)
        print "cooling function initialized..."
        return 0.0
    else:
        return  Lambda_cool.cfunc(np.log10(Tgas))

# %%
from colossus.cosmology import cosmology
from colossus.halo.mass_so import M_to_R
from scipy.interpolate import UnivariateSpline

delta_vir = 100.; 
Zmet = 0.001; z=0.
# some relevant constants
Msun = 1.989e33; kpc = 3.08568e+21; G = 6.67259e-08; yr = 3.15569e+07
mu = 0.6; mp = 1.67262e-24; 
kB = 1.38066e-16; keV = 1.60219e-09
mump = 0.6*mp

# define a vector of cosmological parameters:    
my_cosmo = {'flat': True, 'H0': 70.0, 'Om0': 0.27, 'Ob0': 0.045714, 'sigma8': 0.82, 'ns': 0.96}
# set my_cosmo to be the current cosmology
cosmo = cosmology.setCosmology('my_cosmo', my_cosmo) 


mdef = '200c'
lMhmin, lMhmax = 7., 15.
lm200c = np.arange(lMhmin, lMhmax, 0.02)
m200c = np.power(10.,lm200c)/cosmo.h
r200c = M_to_R(m200c, z, '200c')/cosmo.h
kT200c = 4.3013e4*m200c/r200c*mump
n200c = delta_vir*cosmo.Ob0/cosmo.Om0*cosmo.rho_c(z)*cosmo.h**2*Msun/kpc**3/mump # colossus returns density in h^2 Msun/kpc^3

Lambda_cool(kT200c/kB, Zmet = Zmet, init=True)

tcool = 3.*kT200c/(5.* n200c*10.**Lambda_cool(kT200c/kB,Zmet=Zmet, init=False))/yr


plt.figure(figsize=(2.5,2.5))
plt.xscale('log'); plt.yscale('log')
plt.xlabel(r'$M_{200c}$'); plt.ylabel(r'$t_{\rm cool}\ \mathrm{(yrs)}$')
plt.xlim(1.e9,1e15); plt.ylim(1.e7,1.e12)

# mean matter density rho_crit(z)*Omega0 in h^2 Msun/kpc^3
dmean = 2.77e2
plt.plot(m200c, tcool, c='darkslateblue', lw=2.0, label=r'$\mathrm{t_{\rm cool}\ (yrs)}$')

tU = cosmo.age(z)*np.ones_like(m200c)
plt.plot(m200c, tU*1e9, '--', c='slateblue', lw=2.0, label=r'$\mathrm{age\ of\ the\ universe}$')

plt.grid(linestyle='dotted', c='lightgray')
plt.legend(frameon=False, loc='upper left', fontsize=8)
plt.savefig('fig/tcool_M200c.png', bbox_inches='tight')
plt.show()
# Out:
# cooling function initialized...

# %%
from code.setup.setup import data_home_dir

lTln, cf0ln, hf0ln, cf1ln, hf1ln = np.loadtxt(data_home_dir()+'chf_n1e-3.res',unpack=True) 
lThn, cf0hn, hf0hn, cf1hn, hf1hn = np.loadtxt(data_home_dir()+'chf_n10.0.res',unpack=True) 
#
# plot
#
fig, ax = plt.subplots(1,2, figsize=(6, 3))
xlims = [10., 1.e8]; ylims = [1.e-32, 1.e-20]
ax[0].set_xlabel(r'$T (K)$'); ax[0].set_ylabel(r'$\Lambda(T),\ \mathcal{H}(T)\ \ \mathrm{(cm^3\,erg\, s^{-1})}$')
ax[0].set_xscale('log'); ax[0].set_yscale('log')
ax[0].set_xlim(xlims); ax[0].set_ylim(ylims)
ax[1].set_xscale('log'); ax[1].set_yscale('log')
ax[1].set_xlim(xlims); ax[1].set_ylim(ylims)
ax[1].set_xlabel(r'$T (K)$'); 
plt.setp(ax[1].get_yticklabels(), visible=False)
#ax[1].yaxis.set_label_position('right')


ax[0].plot(10.**lTln, cf0ln, c='c', lw=2.0, label=r'$(Z=0)$')
ax[0].plot(10.**lTln, cf1ln, c='b', lw=2.0, label=r'$(Z=Z_\odot)$')
ax[0].plot(10.**lTln, hf0ln, '--', c='c', lw=2.0)
ax[0].plot(10.**lTln, hf1ln, '--', c='b', lw=2.0, label=r'$\mathcal{H}(T)$')

ax[1].plot(10.**lThn, cf0hn, c='c', lw=2.0, label=r'$Z=0$')
ax[1].plot(10.**lThn, cf1hn, c='b', lw=2.0, label=r'$Z=Z_\odot$')
ax[1].plot(10.**lThn, hf0hn, '--', c='c', lw=2.0)
ax[1].plot(10.**lThn, hf1hn, '--', c='b', lw=2.0, label=r'$\mathcal{H}(T)$')

ax[0].legend( frameon=False, loc='lower left',fontsize=9)
#ax[1].legend( frameon=False, loc='upper left',fontsize=9)
# build a rectangle in axes coords
bottom = 0.25
left = 0.27; height = 0.675
top = bottom + height

ax[0].text(left, top, r'$n=10^{-3}\,\mathrm{cm}^{-3}$',
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax[0].transAxes)
ax[1].text(left, top, r'$n=10\,\mathrm{cm}^{-3}$',
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax[1].transAxes)

ax[0].grid(linestyle='dotted', c='lightgray')
ax[1].grid(linestyle='dotted', c='lightgray')
plt.savefig('fig/chf.png', bbox_inches='tight')
plt.show()

# %%
import code.galaxy_model as gm
from colossus.lss import peaks
from scipy.interpolate import UnivariateSpline
from colossus.halo.concentration import concentration
from colossus.halo.mass_defs import changeMassDefinition
from scipy.integrate import odeint
from code.galaxy_model import R_loss

# some relevant constants
Msun = 1.989e33; kpc = 3.08568e+21; G = 6.67259e-08; 
yr = 3.15569e+07; Gyr = 1.e9 * yr;
mu = 0.6; mp = 1.67262e-24; 
kB = 1.38066e-16; keV = 1.60219e-09
mump = 0.6*mp
delta_vir = 200.

class gmodel_tcool(gm.model_galaxy):
    def __init__(self, *args, **kwargs):
        
        # gas halo mass
        Mgh = kwargs.pop('Mgh')  # Will use 'dict' as default
        if Mgh is not None:
            self.Mgh = Mgh
        else: 
            self.Mgh = 0.0
        self.Mh = kwargs['Mh']; self.t = kwargs['t']
        self.cosmo = kwargs['cosmo']
        Mvir = self.Mh * self.cosmo.h 
        self.z = self.cosmo.age(self.t, inverse=True)        

        Lambda_cool(1., Zmet = 0.01, init=True)
        self.cvir = concentration(Mvir, 'vir', self.z, model='diemer15')
        self.M200c, self.R200c, self.c200c = changeMassDefinition(Mvir, self.cvir, self.z, 'vir', '200c')
        self.M200c /= self.cosmo.h; self.R200c /= self.cosmo.h
        self.kT200c = 4.3013e4*self.M200c/self.R200c*mump
        self.n200c = delta_vir*self.cosmo.rho_b(self.z)*self.cosmo.h**2*Msun/kpc**3/mump # colossus returns density in h^2 Msun/kpc^3
        self.tcool = 3.*self.kT200c/(5.* self.n200c*10.**Lambda_cool(self.kT200c/kB, Zmet=0.01, init=False))/Gyr
        
        # only one model based on total gas density for starters, a better model is to be implemented
        super(gmodel_tcool, self).__init__(*args, **kwargs)

        return
            
    def evolve(self, Mcurrent, t):
        # first set auxiliary quantities and current masses
        self.z = self.cosmo.age(t, inverse=True)        
        self.gr = self.cosmo.growthFactor(self.z)
        self.dDdz = self.cosmo.growthFactor(self.z,derivative=1)
        self.thubble = self.cosmo.hubbleTime(self.z)
        self.dDdt = self.cosmo.growthFactor(self.z, derivative=1) * self.cosmo.age(t, derivative=1, inverse=True)

        self.Mh = Mcurrent[0]; self.Mg = Mcurrent[1]; 
        self.Ms = Mcurrent[2]; self.MZ = Mcurrent[3]
        self.Mgh = Mcurrent[4]
        Mvir = self.Mh * self.cosmo.h
        self.cvir = concentration(Mvir, 'vir', self.z, model='diemer15')
        self.M200c, self.R200c, self.c200c = changeMassDefinition(Mvir, self.cvir, self.z, 'vir', '200c')
        self.M200c /= self.cosmo.h; self.R200c /= self.cosmo.h
        self.kT200c = 4.3013e4*self.M200c/self.R200c*mump
        self.rhobuni = self.cosmo.rho_b(self.z)
        self.fgh = np.maximum(1.e-10, self.Mgh / (self.fbuni*self.Mh))
        self.n200 = delta_vir*self.fgh*self.cosmo.rho_b(self.z)*self.cosmo.h**2*Msun/kpc**3/mump # colossus returns density in h^2 Msun/kpc^3
        self.tcool = 3.*self.kT200c/(5.* self.n200*10.**Lambda_cool(self.kT200c/kB, Zmet=0.01, init=False))/Gyr
        
        self.epsout = self.eps_out(); self.Mgin = self.Mg_in(t); 
        
        self.Msin = self.Ms_in(t)
        self.Rloss = R_loss(0.); self.Rloss1 = 1.0-self.Rloss
        self.sfr = self.SFR(t)
        
        # calculate rates for halo mass, gas mass, stellar mass, and mass of metals
        dMhdtd = self.dMhdt(Mcurrent[0], t)
        dMgdtd = self.dMgdt(Mcurrent[1], t)
        dMsdtd = self.dMsdt(Mcurrent[2], t)
        dMZdtd = self.dMZdt(Mcurrent[3], t)
        dMghdtd = self.dMghdt(Mcurrent[4], t)
        
        if self.verbose:
            print("evolution: t=%2.3f Mh=%.2e, Mg=%.2e, Ms=%.2e, Z/Zsun=%2.2f,SFR=%4.1f, Mgh=%.2e"%(t,self.Mh,self.Mg,self.Ms,
                                                                                           self.MZ/self.Mg/0.02,
                                                                                           self.SFR(t)*1.e-9, self.Mgh))

        return [dMhdtd, dMgdtd, dMsdtd, dMZdtd, dMghdtd]

    def fg_in(self,t):
        return 1.
    
    def dMghdt(self, Mghcurrent, t):

        dummy = self.fbuni*self.fg_in(t)*self.dMhdt(self.Mh,t) - Mghcurrent/self.tcool
        return dummy
    
    def Mg_in(self, t):
        dummy = self.Mgh/self.tcool 
        return dummy
        
def test_galaxy_evolution(gmodel, Minit, sfrmodel, windmodel, etawind, tausf, cosmo, verbose):
    zg = np.linspace(20., 0., 40) # grid of redshifts
    t_output = cosmo.age(zg) # and corresponding times

    # instantiate a galaxy model at t=tinit assuming a given star fromation model and cosmology
    g = gmodel(t = t_output[0], Mh = Minit, Mg = None, Ms = None, MZ = None, Mgh = None, 
                   sfrmodel = sfrmodel, windmodel = windmodel, etawind = etawind, tausf = tausf,  
                   cosmo = cosmo, verbose = verbose)
    
    # array of quantities to evolve with ODE solver
    y0 = np.array([g.Mh, g.Mg, g.Ms, g.MZ, g.Mgh])
    # evolve y0 in time
    Mout = odeint(g.evolve, y0, t_output, rtol = 1.e-7, mxstep = 4000)
    
    # let's split the output into arrays with intuitive names
    Mhout = np.clip(Mout[:,0],0.0,1.e100)
    Mgout = np.clip(Mout[:,1],0.0,1.e100)
    Msout = np.clip(Mout[:,2],0.0,1.e100)
    MZout = np.clip(Mout[:,3],0.0,1.e100)
    Mghout = np.clip(Mout[:,4],0.0,1.e100)

    return zg, t_output, Mhout, Mgout, Msout, MZout, Mghout
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-13f08f362d8c> in <module>()
# ----> 1 import codes.galaxy_model as gm
#       2 from colossus.lss import peaks
#       3 from scipy.interpolate import UnivariateSpline
#       4 from colossus.halo.concentration import concentration
#       5 from colossus.halo.mass_defs import changeMassDefinition
#
# ModuleNotFoundError: No module named 'codes'

# %%
from scipy.interpolate import interp2d

def compute_mass_grid_tcool(gmodel = None, Nz=81, Nm=60, Z_IGM=2.e-5, 
                      sfrmodel='gaslinear', tausf=2.0,  cosmo=None):
    # grid of redshifts and halo masses
    zg = np.linspace(30., 0., Nz)
    lzg1 = np.log10(1.0+zg)
    t_output = cosmo.age(zg)
    
    lMh = np.linspace(5.0, 8., Nm)
    Mh  = np.power(10, lMh)

    # arrays to hold evolutionary grids of halo mass, gas mass, stellar mass and metal mass
    Mhout = np.zeros((Nm,Nz)); Mgout = np.zeros((Nm,Nz))
    Msout = np.zeros((Nm,Nz)); MZout = np.zeros((Nm,Nz))
    Mghout = np.zeros((Nm,Nz)); 
    #evolve a grid of halo masses
    print("evolving mass grid...")
    for j, Mhd in enumerate(Mh):
        #if not j%5:
        #    print "evolving halo of log10(Mh)=%2.2f ..."%(lMh[j])
        # instantiate a model galaxy with a given halo mass at the initial time
        g = gmodel(t = t_output[0], Mh = Mhd, Mg = None, Ms = None, MZ = None, Mgh = None, 
                       Z_IGM = Z_IGM, verbose = False, tausf = 2.0, 
                       sfrmodel = sfrmodel,  cosmo = cosmo)
        # initial values of masses
        y0 = np.array([g.Mh, g.Mg, g.Ms, g.MZ, g.Mgh])
        # solve the system of ODEs
        Mout = odeint(g.evolve, y0, t_output, rtol = 1.e-5, mxstep = 4000)
        # split Mout into arrays for specific masses with more intuitive names for convenience
        Mhout[j,:] = Mout[:,0]; Mgout[j,:] = Mout[:,1]
        Msout[j,:] = Mout[:,2]; MZout[j,:] = Mout[:,3]
        Mghout[j,:] = Mout[:,4]
    print("done.")

    # 
    # prepare 2D splines for interpolation
    #
    Mmin = 1.e-10 # prevent zeros in case no SF occurred
    lMhi = interp2d(lzg1, lMh, np.log10(np.maximum(Mmin,Mhout)), bounds_error=True, kind='cubic')
    lMgi = interp2d(lzg1, lMh, np.log10(np.maximum(Mmin,Mgout)), bounds_error=True, kind='cubic')
    lMsi = interp2d(lzg1, lMh, np.log10(np.maximum(Mmin,Msout)), bounds_error=True, kind='cubic')
    lMZi = interp2d(lzg1, lMh, np.log10(np.maximum(Mmin,MZout)), bounds_error=True, kind='cubic')
    lMghi = interp2d(lzg1, lMh, np.log10(np.maximum(Mmin,Mghout)), bounds_error=True, kind='cubic')

    return lMhi, lMgi, lMsi, lMZi, lMghi

# %%
from colossus.cosmology import cosmology

# define a vector of cosmological parameters:    
my_cosmo = {'flat': True, 'H0': 70.0, 'Om0': 0.27, 'Ob0': 0.045714, 'sigma8': 0.82, 'ns': 0.96}
# set my_cosmo to be the current cosmology
cosmo = cosmology.setCosmology('my_cosmo', my_cosmo)    

lMhitc, lMgitc, lMsitc, lMZitc, lMghitc = compute_mass_grid_tcool(gmodel = gmodel_tcool, 
                                                   Nz=41, Nm=60, Z_IGM=2.e-5, 
                                                   sfrmodel='gaslinear', tausf=2.0, 
                                                   cosmo=cosmo)
# Out:
# evolving mass grid...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# cooling function initialized...
# ...

# %%
# read in M*-Mh relation derived in hw4

mhs, msmh = np.loadtxt(data_home_dir()+'mhmsz0.dat', usecols=(0,1), unpack=True)

# %%
Nm = 81
lMh = np.linspace(5.0, 8., Nm)
Mh  = np.power(10, lMh)
#
# plot
#

fig = plt.figure(figsize=(2.5, 2.5))
plot_pretty()
plt.xlabel(r'$M_h\ \rm (M_\odot)$')
plt.ylabel(r'$M_{\star}\ \rm (M_\odot)$')
plt.xlim(1.e7,1.e15); plt.ylim(1.e4,1.e13)
plt.xscale('log'); plt.yscale('log')

lMhlin = np.linspace(6., 16, 100); Mhlin = 10.**lMhlin
Mslin = Mhlin * cosmo.Ob0/cosmo.Om0
plt.plot(Mhlin, Mslin, ':', c='gray', lw=1.5, label=r'$\Omega_{\rm b}/\Omega_{\rm m}\, M_{\rm h}$')

z_plot = np.array([0., 2.2, 3.5, 6.0])
# colors a la Feldmann for easier comparison
zcolors = ['green', 'red', 'blue', 'darkgray']
for i, zplot in enumerate(z_plot):
    Mhz = 10.**lMhitc(np.log10(1.0+zplot),lMh)
    Msz = 10.**lMsitc(np.log10(1.0+zplot),lMh)
    plt.plot(Mhz, Msz, c=zcolors[i], lw=2.5, label=r'$z=%1.1f$'%zplot)
            

plt.plot(mhs, msmh, c='darkorange', lw=2.5, label=r'$z=0\ \rm AM$')

plt.legend(frameon=False,loc='lower right', fontsize=7)
plt.grid(linestyle='dotted', c='lightgray')
plt.savefig('fig/mhms_Mhotonly_ex.png',bbox_inches='tight')
plt.show()
